# %% [markdown]
# ### Lab 13
# ## Linear Regressions
# ## Jae Choi

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load the data you receive into a Pandas DataFrame.

# %%
insurance_survey= pd.read_csv('insurance.csv')
insurance_survey
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### Show the first five rows of the data set.

# %%
insurance_survey.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### Ensure that any date columns have been cast into a datetime object in your DataFrame.

# %%
x = insurance_survey['age'].values
x
# Out:
# array([19, 18, 28, ..., 18, 21, 61])

# %%
y = insurance_survey['charges'].values
y
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %%
x = x.reshape(-1, 1)
x
# Out:
# array([[19],
#        [18],
#        [28],
#        ...,
#        [18],
#        [21],
#        [61]])

# %% [markdown]
# ### Using a regression model, split your data into train and test data.

# %%
print(f'x_train shape [{x_train.shape}]')
print(f'y_train shape [{y_train.shape}]')
print(f'x_test shape [{x_test.shape}]')
print(f'y_test shape [{y_test.shape}]')
# Out:
# x_train shape [(1070, 1)]
# y_train shape [(1070,)]
# x_test shape [(268, 1)]
# y_test shape [(268,)]

# %% [markdown]
# ### Fit your training split to the regression model.

# %%
plt.scatter(x_train, y_train, color='green')
plt.xlabel('Age')
plt.ylabel('Cost')
plt.title('Insurance Coverage Data')
plt.show()


plt.scatter(x_train, y_train, color='green')
plt.plot(x_test, y_predict)
plt.xlabel('Age')
plt.ylabel('Cost')
plt.title('Insurance Coverage Data')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %% [markdown]
# ### Show your regression model’s score.

# %%
lrm = LinearRegression()
lrm.fit(x_train, y_train)
y_predict = lrm.predict(x_test)
print(f'Train Accuracy {round(lrm.score(x_train, y_train)* 100,2)}%')
print(f'Test Accuracy {round(lrm.score(x_test, y_test)* 100,2)}%')
# Out:
# Train Accuracy 10.51%
# Test Accuracy 2.38%

# %% [markdown]
# ### Draw at least three conclusions from your regression model.
#
# 1. Age does determine if cost of insurance is going to go up
# 2. Test is not very accurate
